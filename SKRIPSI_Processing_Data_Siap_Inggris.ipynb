# %% [markdown]
# <a href="https://colab.research.google.com/github/fornieligulo/Algiritma_NBC/blob/main/SKRIPSI_Processing_Data_Siap_Inggris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 KB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 29.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 KB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 KB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 KB 6.0 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16368 sha256=2e63f665ac3d7708db5d098e88aed79ecd2bd51cf6b3906747c66e776ae04ea7
#   Stored in directory: /root/.cache/pip/wheels/ae/e1/6c/5137bc3f35aa130deea71575e165cc4f4f0680a88f3d90a636
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
import pandas as pd
import googletrans
from googletrans import Translator

# %%
def load_data():
    data = pd.read_csv('04-Hasi-Preprocessing-Data.csv')
    return data

tweet_df = load_data()
tweet_df.head()
# Out:
#           username        date      time  replies_count  retweets_count  \
# 0        epadmaaaw  11/03/2023  11:18:09              1               0
# 1  molwantwa_sambo  30/07/2022  14:34:11              1               1
# 2    kangkungkukus  14/07/2022  14:06:25              5               3
# 3  molwantwa_sambo  25/11/2022  22:08:08              1               0
# 4  molwantwa_sambo  30/08/2022  22:54:44              1               0
#
#    likes_count                                              Tweet
# 0            0                                                NaN
# 1            5  a hi yimeni hi yimisa ndhuna hosi mi delela ng...
# 2           21  a istri irjen b brigadir j c bharada e a b sel...
# 3            1                          a ndzi joli na swi hlangi
# 4            2                               a ndzi lava ku ya ba

# %%
#definisi dataframe
#ubah dataframe sesuai column kalian
df  = pd.DataFrame(tweet_df[['username','date','time','replies_count','retweets_count','likes_count','Tweet']])
df
# Out:
#               username        date      time  replies_count  retweets_count  \
# 0            epadmaaaw  11/03/2023  11:18:09              1               0
# 1      molwantwa_sambo  30/07/2022  14:34:11              1               1
# 2        kangkungkukus  14/07/2022  14:06:25              5               3
# 3      molwantwa_sambo  25/11/2022  22:08:08              1               0
# 4      molwantwa_sambo  30/08/2022  22:54:44              1               0
# ...                ...         ...       ...            ...             ...
# 15711          herjobi  23/02/2023  11:29:54              1               0
# 15712        reezalino  01/11/2022   8:57:04              1               0
# 15713  zoelhelmilubis1  18/01/2023  17:55:49              1               0
# 15714      abd_al_bary  30/09/2022   2:15:15              1               0
# 15715    bensin_sachet  18/10/2022  13:03:37              1               1
#
# ...

# %%
translator = Translator()
translations = {}
for column in df.columns:
  unique_elements = df[column].unique()
  for element in unique_elements:
    translations[element] = translator.translate(element).text
translations
# Out:
# {'epadmaaaw': "I'm sorry",
#  'molwantwa_sambo': 'molwantwa_sambo',
#  'kangkungkukus': 'kangkungkus',
#  'kobamyashi': 'refuse',
#  'putri_nfpn14': 'princess_nfpn14',
#  'rep_rakyatchika': 'Rep_rakya t chika',
#  'lmh1640': 'lmh1640',
#  'realsambofatiu': 'realsambofatiu',
#  'natasha_nia8': 'natasha ni 8',
#  'alfxrxs910': 'alfxrxs910',
#  'sambo_fredi': 'sambo_fredi',
#  'hardiminardi': 'hardiminardi',
#  'drevachaniago': 'drevachaniago',
#  'al_nayz': 'meteorites',
#  'diamentesicess': 'diamentesicess',
#  'itlumnikufesin': 'itlumkufessin',
#  'gelarlarge': 'gellarge',
#  'maspiqi': 'Temper immediately',
#  'pnsdaerahjelata': 'Bensdrgelta',
#  'ny3t_': 'obituary',
#  'ya_adiva': 'ya_adiva',
#  'bonitanitamauls': 'bonitanitamauls',
#  'faradillaanggii': 'the horse',
#  'atiygom': 'athyogome',
#  'gurubaran_off': 'guruburn_off',
#  'unailysm': 'unailysm',
#  'viriting': 'viriting',
#  'lyndaibrahim': 'lyndaibrahim',
#  'dwitanihboss': 'dwitanihboss',
#  'tara_tr': 'country_tr',
# ...

# %%
#mengganti semua kata yang di terjemakan dari kamus original dataframe
df.replace(translations, inplace = True)
df
# Out:
#               username        date      time replies_count retweets_count  \
# 0            I'm sorry  11/03/2023  11:18:09             1              0
# 1      molwantwa_sambo  30/07/2022  14:34:11             1              1
# 2          kangkungkus  14/07/2022  14:06:25             5              3
# 3      molwantwa_sambo  25/11/2022  22:08:08             1              0
# 4      molwantwa_sambo  30/08/2022  22:54:44             1              0
# ...                ...         ...       ...           ...            ...
# 15711     military job  23/02/2023  11:29:54             1              0
# 15712        reizalino  01/11/2022   8:57:04             1              0
# 15713  zoelhelmilubis1  18/01/2023  17:55:49             1              0
# 15714       Abd Albari  30/09/2022   2:15:15             1              0
# 15715  sachet gasoline  18/10/2022  13:03:37             1              1
#
#       likes_count                                              Tweet
# ...

# %%
df.to_csv('05-Data_translate_processing_tweet.csv',encoding='utf8', index=False)

# %%
import pandas as pandas
def load_data():
  data = pd.read_csv('05-Data_translate_processing_tweet.csv')
  return data

# %%
tweet_df = load_data()
tweet_df.head()
# Out:
#           username        date      time  replies_count  retweets_count  \
# 0        I'm sorry  11/03/2023  11:18:09              1               0
# 1  molwantwa_sambo  30/07/2022  14:34:11              1               1
# 2      kangkungkus  14/07/2022  14:06:25              5               3
# 3  molwantwa_sambo  25/11/2022  22:08:08              1               0
# 4  molwantwa_sambo  30/08/2022  22:54:44              1               0
#
#    likes_count                                              Tweet
# 0            0                                                 in
# 1            5  let's stand up and stop the chief king you des...
# 2           21  a wife of the inspector general b brigadier j ...
# 3            1                                  i don't date kids
# 4            2                                 i wanted to go bat

# %%
# !pip install VaderSentiment
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 KB 11.3 MB/s eta 0:00:00
# ...

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
scores = [analyser.polarity_scores(x) for x in tweet_df['Tweet']]
print(scores)
tweet_df['Compound_Score'] = [x['compound'] for x in scores]

tweet_df.head(5)
# Out:
# [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.169, 'neu': 0.831, 'pos': 0.0, 'compound': -0.7096}, {'neg': 0.216, 'neu': 0.756, 'pos': 0.028, 'compound': -0.9217}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.057, 'neu': 0.654, 'pos': 0.288, 'compound': 0.8834}, {'neg': 0.052, 'neu': 0.61, 'pos': 0.338, 'compound': 0.9386}, {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.0772}, {'neg': 0.274, 'neu': 0.496, 'pos': 0.229, 'compound': -0.3304}, {'neg': 0.0, 'neu': 0.488, 'pos': 0.512, 'compound': 0.2732}, {'neg': 0.0, 'neu': 0.892, 'pos': 0.108, 'compound': 0.3182}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.0, 'neu': 0.359, 'pos': 0.641, 'compound': 0.6549}, {'neg': 0.0, 'neu': 0.935, 'pos': 0.065, 'co
# ...

# %%
tweet_df.loc[tweet_df['Compound_Score'] < 0, 'Sentiments'] = 'Negatif'
tweet_df.loc[tweet_df['Compound_Score'] == 0, 'Sentiments'] = 'Netral'
tweet_df.loc[tweet_df['Compound_Score'] > 0, 'Sentiments'] = 'Positif'
tweet_df.head()
# Out:
#           username        date      time  replies_count  retweets_count  \
# 0        I'm sorry  11/03/2023  11:18:09              1               0
# 1  molwantwa_sambo  30/07/2022  14:34:11              1               1
# 2      kangkungkus  14/07/2022  14:06:25              5               3
# 3  molwantwa_sambo  25/11/2022  22:08:08              1               0
# 4  molwantwa_sambo  30/08/2022  22:54:44              1               0
#
#    likes_count                                              Tweet  \
# 0            0                                                 in
# 1            5  let's stand up and stop the chief king you des...
# 2           21  a wife of the inspector general b brigadier j ...
# 3            1                                  i don't date kids
# 4            2                                 i wanted to go bat
#
#    Compound_Score Sentiments
# 0          0.0000     Netral
# 1         -0.7096    Negatif
# 2         -0.9217    Negatif
# ...

# %%
tweet_df.to_csv('06-Data_sentiment_processing_tweet inggris.csv',encoding='utf8', index=False)

# %%
s = pd.value_counts(tweet_df['Sentiments'])
ax = s.plot.bar()
n = len(tweet_df.index)
print(n)
for p in ax.patches:
  ax.annotate(str(round(p.get_height() / n*100, 2)) + '%', (p.get_x() * 1.005, p.get_height() *1.005))
# Out:
# 15716

# %%
import pandas as pandas
import pandas as pd

def load_data():
  data = pd.read_csv('Data_sentiment_processing_tweet inggris.csv')
  return data
