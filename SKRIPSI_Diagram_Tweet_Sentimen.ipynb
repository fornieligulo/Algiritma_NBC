# %% [markdown]
# <a href="https://colab.research.google.com/github/fornieligulo/Algiritma_NBC/blob/main/SKRIPSI_Diagram_Tweet_Sentimen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Analisis Sentiment Juli 2022**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('2_Juli 2022.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Juli 2022', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment Agustus 2022**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('3_Agustus 2022.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Agustus 2022', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment September 2022**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('4_September 2022.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment September 2022', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment Oktober 2022**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('5_Oktober 2022.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Oktober 2022', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment November 2022**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('6_November 2022.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment November 2022', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment Desember 2022**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('7_Desember 2022.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Desember 2022', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment Januari 2023**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('8_Januari 2023.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Januari 2023', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment Februari 2023**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('9_Februari 2023.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Februari 2023', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment Maret 2023**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('10_Maret 2023.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Maret 2023', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment Juli 2022 - Januari 2023**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('11_Juli2022 - Jan2023.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Juli 2022 - Januari 2023', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment Februari -  Maret 2023**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('12_Feb - Mar 2023.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Februari - Maret 2023', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # **Analisis Sentiment Juli 2022 - Maret 2023**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
df = pd.read_excel('1_06-Data-Sentimen.xlsx')

# count the number of each sentiment
sentiment_count = df['Sentiments'].value_counts()

# set plot style
sns.set_style('whitegrid')

# create a bar plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.barplot(x=sentiment_count.index, y=sentiment_count.values, palette='pastel')
plt.title('Analisis Sentiment Juli 2022 - Maret 2023', fontsize=18, pad=20)
plt.xlabel('Class Sentiment',fontsize=14)
plt.ylabel('Jumlah Tweet', fontsize=14)

# add labels above each bar
for i, count in enumerate(sentiment_count.values):
    ax.text(i, count+0.10, str(count), ha='center', va='bottom')

plt.show()
